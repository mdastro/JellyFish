# %%
import numpy             as np
import pandas            as pd
import matplotlib.pyplot as plt
import seaborn           as sns
import astropy.io.fits   as fits
from astropy.visualization import astropy_mpl_style as astyle
from astropy.utils.data    import get_pkg_data_filename as get
from matplotlib.colors import LogNorm
from matplotlib.colors import PowerNorm

# %%
image_isdss = '../../Dados/A370/iSDSS/images/j04-20181003T234351-01_proc.fz'
image_j010  = '../../Dados/A370/J0910/images/j04-20181004T010944-01_proc.fz'

# %%
fit_isdss = fits.open(image_isdss)
fit_j010  = fits.open(image_j010)

# %%
fit_isdss.info()
# Out:
# Filename: ../../Dados/A370/iSDSS/images/j04-20181003T234351-01_proc.fz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       8   ()
#   1  COMPRESSED_IMAGE    1 CompImageHDU    830   (7777, 8473)   float32
#   2  MASKED PIXELS    1 CompImageHDU     19   (7777, 8473)   uint8

# %%
header = fit_isdss[1].header

# %%
header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 7777
# NAXIS2  =                 8473
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# XTENSION= 'BINTABLE'           / binary table extension
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# BUNIT   = 'adu'
# ORIGIN  = 'OAJ'
# FILENAME= 'j04-20181003T234351-01_proc.fits'
# TELESCOP= 'OAJ-T250'
# INSTRUME= 'Pathfinder'
# OBJECT  = 'A370'
# PRJ_ID  = '1000003'
# PRJ_VER = 'DEFAULT_PRJ_VER'
# OBS_ID  = 'miniJPAS'
# EXP_ID  = 'DEFAULT_EXP_ID'
# OBSERVER= 'HMI'
# PI-COI  = 'DEFAULT_PICOI'
# ORIGFILE= 'j04-20181003T234351-01.fits.fz'
# DATE    = '2018-10-03T23:44:41.774'
# ...

# %%
image_isdss = get(image_isdss)
image_isdss_data = fits.getdata(image_isdss, ext=0)

# %%
image_j010 = get(image_j010)
image_j010_data = fits.getdata(image_j010, ext=0)

# %%
# %matplotlib notebook
plt.style.use(astyle)
plt.figure(figsize=(10,8))
plt.imshow(image_j010_data, cmap='gray', norm=LogNorm(vmin=1e2, vmax=2e3))
# plt.imshow(image_j010_data, cmap='gray', norm=PowerNorm(gamma(vmin=1, vmax=400)))

plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
cat = '../../Dados/A370/iSDSS/cat/j04-20181003T234351-01_proc.proccat'

# %%
cat_01 = fits.open(cat)

# %%
table = cat_01[1]

# %%
table.name
# Out:
# 'LDAC_IMHEAD'

# %%
table_array = np.array(table.data)

# %%
table_array.shape
# Out:
# (2738,)

# %%
2738/37
# Out:
# 74.0

# %%
table_array[0][20]
# Out:
# 0.057991844

# %%
len([15.215133, 16.813768, 16.32163 , 15.92118 , 15.579839, 15.389289, 15.234609, 15.125345, 15.171585, 15.424303, 15.279953, 15.389087, 99.      , 99.      , 99.      , 16.08862 , 15.338113, 15.144559, 15.142197, 15.348874])
# Out:
# 20
